# %% [markdown]
# # Show the dataframe shape.

# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\Benutzer1\Ironhack\Week_1\Day_2\Afternoon\lab-customer-analysis-round-2\files_for_lab\csv_files\marketing_customer_analysis.csv')

# %%
df.shape
# Out:
# (10910, 26)

# %%
df.head()
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# 0                        0.0                  9  Corporate Auto  Corporate L3
# 1                        0.0                  1   Personal Auto   Personal L3
# 2                        0.0                  2   Personal Auto   Personal L3
# 3                        0.0                  2  Corporate Auto  Corporate L3
# 4                        NaN                  7   Personal Auto   Personal L2
#
#    Renew Offer Type  Sales Channel  Total Claim Amount  Vehicle Class  \
# 0            Offer3          Agent          292.800000  Four-Door Car
# 1            Offer4    Call Center          744.924331  Four-Door Car
# 2            Offer3    Call Center          480.000000            SUV
# 3            Offer2         Branch          484.013411  Four-Door Car
# 4            Offer1         Branch          707.925645  Four-Door Car
#
#   Vehicle Size Vehicle Type
# 0      Medsize          NaN
# 1      Medsize          NaN
# 2      Medsize            A
# 3      Medsize            A
# 4      Medsize          NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# # Standardize header names.

# %%
df.columns.unique()
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
df2=df.copy()

# %%
cols = []
for column in df2.columns:
    cols.append(column.lower())
df2.columns = cols

# %%
df2.columns.unique()
# Out:
# Index(['unnamed: 0', 'customer', 'state', 'customer lifetime value',
#        'response', 'coverage', 'education', 'effective to date',
#        'employmentstatus', 'gender', 'income', 'location code',
#        'marital status', 'monthly premium auto', 'months since last claim',
#        'months since policy inception', 'number of open complaints',
#        'number of policies', 'policy type', 'policy', 'renew offer type',
#        'sales channel', 'total claim amount', 'vehicle class', 'vehicle size',
#        'vehicle type'],
#       dtype='object')

# %%
def standerlize(x):
    if ( ' ' in x ):
        x = x.replace(" ","_")
    return x
standerlize('we can')
# Out:
# 'we_can'

# %%
df2.columns = df2.columns.to_series().apply(standerlize)
df2.columns.unique()
df2=df2.drop('unnamed:_0',axis=1)

# %%
df2.columns.unique()
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size', 'vehicle_type'],
#       dtype='object')

# %% [markdown]
# # Which columns are numerical?

# %%
import numpy as np

# %%
df2.select_dtypes(np.number)
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# 2                         34.0                             31
# 3                         10.0                              3
# 4                          NaN                             31
# ...                        ...                            ...
# 10905                      NaN                             40
# 10906                      7.0                             68
# 10907                     11.0                             63
# 10908                      0.0                             27
# 10909                     31.0                              1
#
#        number_of_open_complaints  number_of_policies  total_claim_amount
# 0                            0.0                   9          292.800000
# 1                            0.0                   1          744.924331
# 2                            0.0                   2          480.000000
# 3                            0.0                   2          484.013411
# 4                            NaN                   7          707.925645
# ...                          ...                 ...                 ...
# 10905                        NaN                   7         1214.400000
# 10906                        0.0                   6          273.018929
# 10907                        0.0                   2          381.306996
# 10908                        4.0                   6          618.288849
# 10909                        0.0                   3         1021.719397
#
# [10910 rows x 8 columns]

# %% [markdown]
# # Which columns are catagorical?

# %%
df2.select_dtypes('object')
# Out:
#       customer       state response  coverage education effective_to_date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       employmentstatus gender location_code marital_status     policy_type  \
# 0             Employed      M      Suburban        Married  Corporate Auto
# 1           Unemployed      F      Suburban         Single   Personal Auto
# 2             Employed      M      Suburban         Single   Personal Auto
# 3             Employed      M      Suburban         Single  Corporate Auto
# 4        Medical Leave      F      Suburban        Married   Personal Auto
# ...                ...    ...           ...            ...             ...
# 10905       Unemployed      F      Suburban        Married   Personal Auto
# 10906         Employed      F         Urban        Married   Personal Auto
# 10907         Employed      F         Rural        Married  Corporate Auto
# 10908         Employed      F         Urban       Divorced   Personal Auto
# 10909       Unemployed      M      Suburban         Single   Personal Auto
#
#              policy renew_offer_type sales_channel  vehicle_class  \
# 0      Corporate L3           Offer3         Agent  Four-Door Car
# 1       Personal L3           Offer4   Call Center  Four-Door Car
# 2       Personal L3           Offer3   Call Center            SUV
# 3      Corporate L3           Offer2        Branch  Four-Door Car
# 4       Personal L2           Offer1        Branch  Four-Door Car
# ...             ...              ...           ...            ...
# 10905   Personal L1           Offer3           Web     Luxury Car
# 10906   Personal L3           Offer2        Branch  Four-Door Car
# 10907  Corporate L3           Offer1           Web     Luxury SUV
# 10908   Personal L1           Offer1        Branch            SUV
# 10909   Personal L1           Offer4           Web            SUV
#
#       vehicle_size vehicle_type
# 0          Medsize          NaN
# 1          Medsize          NaN
# 2          Medsize            A
# 3          Medsize            A
# 4          Medsize          NaN
# ...            ...          ...
# 10905      Medsize            A
# 10906      Medsize            A
# 10907      Medsize          NaN
# 10908      Medsize            A
# 10909      Medsize          NaN
#
# [10910 rows x 17 columns]

# %% [markdown]
# # Check and deal with NaN values.

# %%
df2.isna().sum()
# Out:
# customer                            0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           633
# months_since_policy_inception       0
# number_of_open_complaints         633
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# vehicle_type                     5482
# dtype: int64

# %%
df2[df2['vehicle_class'].isna()==True].head(60)
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 87    ZH92587      Oregon              8126.766397       No     Basic
# 88    CJ51511     Arizona             13466.920710      Yes     Basic
# 89    ME37450     Arizona              5210.348372       No     Basic
# 97    CA22248      Oregon              2505.420430       No     Basic
# 148   HB24005  California              2347.048112       No     Basic
# 163   TP34946  California              5108.038755       No     Basic
# 186   BG42047      Nevada              2511.944048       No     Basic
# 205   YZ19736     Arizona              2580.849899      Yes     Basic
# 224   KL65897  California              6331.338496       No  Extended
# 261   HZ56678      Oregon              2780.196856       No     Basic
# 294   AM57175      Oregon             15000.842380       No  Extended
# 301   JP35025  California              5714.165863       No     Basic
# 346   YC69616     Arizona              2719.506996      Yes     Basic
# 367   VY90611  California              2499.036551       No     Basic
# 397   XV69290  California             22332.439460      Yes  Extended
# 416   EO40136     Arizona              2912.248444       No     Basic
# 426   GE82737      Nevada              5337.352409       No  Extended
# 448   GT66241  California              2414.072446       No     Basic
# 457   BZ85280      Oregon              7284.262288       No     Basic
# 480   EC71986  Washington              2429.280527       No     Basic
# 489   GU42671     Arizona              6106.941981       No  Extended
# 491   IE97795         NaN              6878.008403      NaN  Extended
# 494   AY55759  California             20096.893370      Yes     Basic
# 547   FL85008      Oregon             13466.920710      Yes     Basic
# 554   AU23837      Oregon              5010.379310       No     Basic
# 577   GQ46925     Arizona              5821.684337       No   Premium
# 586   GZ79662     Arizona              5484.588155       No     Basic
# 601   OA92714  California              5055.902381       No     Basic
# 634   DH34004  California              6191.402312       No     Basic
# 636   HM94328     Arizona              6047.025160      Yes  Extended
# 644   SK12432     Arizona              2388.353882       No     Basic
# 650   JP58047      Oregon              8332.730557       No  Extended
# 668   KH58171  California              2551.226692      Yes     Basic
# 672   GJ47397      Oregon             38055.209530       No     Basic
# 679   EZ41764  California              2498.963061       No     Basic
# 683   KC36987      Oregon             13334.267630       No   Premium
# 691   ID89933      Oregon              7255.577594       No  Extended
# 716   ZZ49347      Oregon              2592.437797      Yes     Basic
# 718   KW95891      Oregon              2635.148447       No     Basic
# 744   KH24214         NaN             17857.972330      NaN     Basic
# 756   VX85673     Arizona              4250.282624      Yes     Basic
# 761   XH47320      Nevada              2937.424534       No     Basic
# 786   HF11584     Arizona             12913.498180       No     Basic
# 856   CF62992      Oregon              2471.077732       No     Basic
# 888   ED28429  Washington              4159.593921       No     Basic
# 929   BB11622      Nevada             10552.169990       No  Extended
# 933   YT91759  California              6366.225775      Yes  Extended
# 950   ID89933      Oregon              7255.577594       No  Extended
# 972   MG46007  California              6358.251692       No  Extended
# 979   BA52133  California              5344.989624       No     Basic
# 982   TK61994      Oregon              6104.501453       No  Extended
# 993   MQ68407      Oregon              4376.363592      Yes   Premium
# 1024  VE72838     Arizona             13770.976180      Yes   Premium
# 1046  LD75023      Oregon             26346.085820       No  Extended
# 1065  BU72633      Nevada             42561.631830       No     Basic
# 1075  ES57969      Oregon              2453.570794      Yes     Basic
# 1078  YI73667      Nevada              5340.810309       No     Basic
# 1109  CE72177  California              5461.548993       No     Basic
# 1127  ZW19492      Oregon              2404.917967       No     Basic
# 1130  XW96958      Nevada              7573.345057       No   Premium
#
#                  education effective_to_date employmentstatus gender  income  \
# 87                 College           2/22/11         Disabled      F   14616
# 88    High School or Below           2/23/11         Disabled      F   11432
# 89                Bachelor            1/4/11         Employed      M   89781
# 97                  Master           2/14/11         Employed      F   60546
# 148                College            2/2/11         Employed      M   31617
# 163                College            1/9/11         Disabled      M   26784
# 186                College           1/15/11    Medical Leave      M   17658
# 205                College            2/9/11         Employed      M   46900
# 224               Bachelor           2/21/11       Unemployed      F       0
# 261   High School or Below           1/12/11         Disabled      F   20261
# 294   High School or Below            1/6/11         Employed      F   62473
# 301                 Master           2/23/11         Disabled      F   23726
# 346                College           1/24/11          Retired      F   14030
# 367                 Master           1/27/11         Employed      F   28264
# 397                College           1/11/11         Employed      M   49078
# 416                College           1/24/11         Employed      F   93403
# 426               Bachelor           2/14/11       Unemployed      F       0
# 448   High School or Below            1/8/11       Unemployed      M       0
# 457                College           2/23/11    Medical Leave      M   10334
# 480   High School or Below           1/18/11    Medical Leave      F   26736
# 489               Bachelor           2/21/11    Medical Leave      F   16654
# 491   High School or Below            2/5/11         Employed      M   39020
# 494   High School or Below            1/1/11         Employed      F   92766
# 547   High School or Below           2/23/11         Disabled      F   11432
# 554               Bachelor           1/19/11         Employed      F   64014
# 577   High School or Below           2/15/11         Employed      M   77563
# 586   High School or Below           2/21/11         Employed      M   47611
# 601               Bachelor           1/10/11         Employed      F   88989
# 634                College            2/6/11       Unemployed      M       0
# 636                College           2/19/11         Employed      M   20396
# 644               Bachelor           2/14/11       Unemployed      M       0
# 650                College           1/27/11       Unemployed      M       0
# 668                 Master           1/19/11         Employed      M   79751
# 672   High School or Below           2/12/11       Unemployed      M       0
# 679               Bachelor           2/26/11         Employed      M   76792
# 683               Bachelor           1/20/11         Employed      M   47950
# 691                 Doctor            1/9/11         Employed      F   39786
# 716   High School or Below            1/2/11         Employed      M   72421
# 718   High School or Below           1/28/11         Employed      F   93884
# 744                College           2/13/11         Employed      M   55437
# 756   High School or Below           1/18/11       Unemployed      F       0
# 761                 Master           1/10/11         Employed      F   83195
# 786                 Master           1/11/11         Employed      M   62448
# 856   High School or Below           1/16/11         Employed      F   53074
# 888               Bachelor            2/1/11       Unemployed      M       0
# 929                 Master            1/2/11         Employed      M   47761
# 933   High School or Below            1/7/11         Employed      M   44368
# 950                 Doctor            1/9/11         Employed      F   39786
# 972   High School or Below           1/24/11       Unemployed      M       0
# 979                 Master           2/11/11         Employed      M   22908
# 982                College           2/28/11         Disabled      F   18690
# 993               Bachelor           2/28/11         Employed      F   63774
# 1024  High School or Below            2/1/11         Employed      F   59207
# 1046  High School or Below           1/20/11         Employed      M   48268
# 1065                Master           1/10/11         Employed      M   66661
# 1075              Bachelor            2/9/11    Medical Leave      M   29735
# 1078               College           1/17/11       Unemployed      F       0
# 1109  High School or Below            1/7/11         Employed      F   39626
# 1127              Bachelor           2/14/11         Employed      M   63455
# 1130  High School or Below           2/20/11       Unemployed      M       0
#
#       ... number_of_open_complaints number_of_policies     policy_type  \
# 87    ...                       NaN                  3   Personal Auto
# 88    ...                       NaN                  2  Corporate Auto
# 89    ...                       0.0                  5    Special Auto
# 97    ...                       0.0                  1   Personal Auto
# 148   ...                       1.0                  1   Personal Auto
# 163   ...                       0.0                  8  Corporate Auto
# 186   ...                       0.0                  1   Personal Auto
# 205   ...                       0.0                  1   Personal Auto
# 224   ...                       0.0                  3   Personal Auto
# 261   ...                       0.0                  1   Personal Auto
# 294   ...                       1.0                  2   Personal Auto
# 301   ...                       0.0                  9  Corporate Auto
# 346   ...                       0.0                  1   Personal Auto
# 367   ...                       NaN                  1  Corporate Auto
# 397   ...                       0.0                  2  Corporate Auto
# 416   ...                       0.0                  1   Personal Auto
# 426   ...                       3.0                  5   Personal Auto
# 448   ...                       0.0                  1   Personal Auto
# 457   ...                       0.0                  2   Personal Auto
# 480   ...                       0.0                  1   Personal Auto
# 489   ...                       0.0                  7   Personal Auto
# 491   ...                       0.0                  5  Corporate Auto
# 494   ...                       0.0                  2   Personal Auto
# 547   ...                       0.0                  2   Personal Auto
# 554   ...                       0.0                  7  Corporate Auto
# 577   ...                       0.0                  1   Personal Auto
# 586   ...                       0.0                  4  Corporate Auto
# 601   ...                       1.0                  3   Personal Auto
# 634   ...                       3.0                  1   Personal Auto
# 636   ...                       1.0                  4  Corporate Auto
# 644   ...                       0.0                  1   Personal Auto
# 650   ...                       0.0                  2   Personal Auto
# 668   ...                       0.0                  1   Personal Auto
# 672   ...                       0.0                  2    Special Auto
# 679   ...                       0.0                  1   Personal Auto
# 683   ...                       1.0                  8   Personal Auto
# 691   ...                       NaN                  9   Personal Auto
# 716   ...                       0.0                  1   Personal Auto
# 718   ...                       0.0                  1   Personal Auto
# 744   ...                       1.0                  2   Personal Auto
# 756   ...                       1.0                  7   Personal Auto
# 761   ...                       1.0                  1   Personal Auto
# 786   ...                       0.0                  2   Personal Auto
# 856   ...                       0.0                  1   Personal Auto
# 888   ...                       0.0                  3   Personal Auto
# 929   ...                       0.0                  6   Personal Auto
# 933   ...                       0.0                  3   Personal Auto
# 950   ...                       1.0                  9   Personal Auto
# 972   ...                       2.0                  4   Personal Auto
# 979   ...                       0.0                  7   Personal Auto
# 982   ...                       0.0                  5   Personal Auto
# 993   ...                       0.0                  1   Personal Auto
# 1024  ...                       0.0                  2   Personal Auto
# 1046  ...                       0.0                  2   Personal Auto
# 1065  ...                       0.0                  2   Personal Auto
# 1075  ...                       0.0                  1   Personal Auto
# 1078  ...                       0.0                  6   Personal Auto
# 1109  ...                       0.0                  3   Personal Auto
# 1127  ...                       0.0                  1   Personal Auto
# 1130  ...                       0.0                  6  Corporate Auto
#
#             policy  renew_offer_type  sales_channel  total_claim_amount  \
# 87     Personal L3            Offer1          Agent          513.600000
# 88    Corporate L3            Offer2          Agent          571.200000
# 89      Special L2            Offer1          Agent           37.960537
# 97     Personal L3            Offer2         Branch           46.278027
# 148    Personal L1            Offer1          Agent          244.269407
# 163   Corporate L3            Offer3         Branch          482.400000
# 186    Personal L3            Offer3            Web          312.000000
# 205    Personal L2            Offer2            Web          316.800000
# 224    Personal L2            Offer1         Branch           94.714302
# 261    Personal L2            Offer4            Web          345.600000
# 294    Personal L3            Offer1         Branch          507.560729
# 301   Corporate L1            Offer1    Call Center          355.200000
# 346    Personal L3            Offer2         Branch          345.600000
# 367   Corporate L3            Offer2          Agent          364.622773
# 397   Corporate L2            Offer2         Branch          484.013411
# 416    Personal L2            Offer2            Web          295.224598
# 426    Personal L3            Offer1          Agent          619.200000
# 448    Personal L3            Offer2    Call Center          511.200000
# 457    Personal L1            Offer3          Agent          296.962938
# 480    Personal L1            Offer1          Agent          367.927730
# 489    Personal L3            Offer1         Branch          379.200000
# 491   Corporate L1            Offer3          Agent          485.013840
# 494    Personal L2            Offer2          Agent          379.029102
# 547    Personal L2            Offer2          Agent          571.200000
# 554   Corporate L3            Offer1          Agent          295.871784
# 577    Personal L1            Offer4    Call Center          545.999699
# 586   Corporate L3            Offer2    Call Center          593.654484
# 601    Personal L3            Offer3    Call Center          232.745161
# 634    Personal L3            Offer2            Web          955.200000
# 636   Corporate L2            Offer1         Branch          364.800000
# 644    Personal L1            Offer2            Web          677.970934
# 650    Personal L3            Offer2            Web          379.200000
# 668    Personal L3            Offer3            Web          392.235698
# 672     Special L2            Offer2          Agent          552.000000
# 679    Personal L2            Offer3          Agent          297.600000
# 683    Personal L3            Offer1         Branch          780.990942
# 691    Personal L2            Offer1            Web          365.835977
# 716    Personal L3            Offer2    Call Center          312.000000
# 718    Personal L3            Offer4         Branch          312.000000
# 744    Personal L3            Offer3          Agent          445.287788
# 756    Personal L3            Offer1          Agent          292.800000
# 761    Personal L1            Offer1    Call Center          332.693627
# 786    Personal L3            Offer1         Branch          513.600000
# 856    Personal L2            Offer1          Agent          268.773368
# 888    Personal L1            Offer1          Agent          446.400000
# 929    Personal L3            Offer1          Agent          232.711071
# 933    Personal L2            Offer2    Call Center          384.000000
# 950    Personal L2            Offer1            Web          365.835977
# 972    Personal L2            Offer1          Agent           17.938979
# 979    Personal L2            Offer3    Call Center          387.774781
# 982    Personal L2            Offer1          Agent           18.192921
# 993    Personal L3            Offer2          Agent           60.036683
# 1024   Personal L3            Offer1          Agent          556.800000
# 1046   Personal L2            Offer1            Web         1605.600000
# 1065   Personal L2            Offer1          Agent          571.200000
# 1075   Personal L2            Offer1          Agent          331.200000
# 1078   Personal L3            Offer2            Web          345.600000
# 1109   Personal L3            Offer2          Agent          485.705851
# 1127   Personal L3            Offer1         Branch          287.654819
# 1130  Corporate L3            Offer1          Agent         1193.036154
#
#      vehicle_class vehicle_size vehicle_type
# 87             NaN          NaN          NaN
# 88             NaN          NaN          NaN
# 89             NaN          NaN            A
# 97             NaN          NaN            A
# 148            NaN          NaN            A
# 163            NaN          NaN          NaN
# 186            NaN          NaN            A
# 205            NaN          NaN            A
# 224            NaN          NaN            A
# 261            NaN          NaN            A
# 294            NaN          NaN          NaN
# 301            NaN          NaN            A
# 346            NaN          NaN            A
# 367            NaN          NaN            A
# 397            NaN          NaN          NaN
# 416            NaN          NaN          NaN
# 426            NaN          NaN            A
# 448            NaN          NaN          NaN
# 457            NaN          NaN          NaN
# 480            NaN          NaN          NaN
# 489            NaN          NaN            A
# 491            NaN          NaN            A
# 494            NaN          NaN          NaN
# 547            NaN          NaN          NaN
# 554            NaN          NaN            A
# 577            NaN          NaN          NaN
# 586            NaN          NaN          NaN
# 601            NaN          NaN            A
# 634            NaN          NaN            A
# 636            NaN          NaN            A
# 644            NaN          NaN            A
# 650            NaN          NaN            A
# 668            NaN          NaN          NaN
# 672            NaN          NaN            A
# 679            NaN          NaN          NaN
# 683            NaN          NaN          NaN
# 691            NaN          NaN          NaN
# 716            NaN          NaN            A
# 718            NaN          NaN          NaN
# 744            NaN          NaN          NaN
# 756            NaN          NaN          NaN
# 761            NaN          NaN            A
# 786            NaN          NaN          NaN
# 856            NaN          NaN          NaN
# 888            NaN          NaN            A
# 929            NaN          NaN          NaN
# 933            NaN          NaN          NaN
# 950            NaN          NaN            A
# 972            NaN          NaN            A
# 979            NaN          NaN          NaN
# 982            NaN          NaN            A
# 993            NaN          NaN            A
# 1024           NaN          NaN            A
# 1046           NaN          NaN            A
# 1065           NaN          NaN          NaN
# 1075           NaN          NaN            A
# 1078           NaN          NaN            A
# 1109           NaN          NaN            A
# 1127           NaN          NaN            A
# 1130           NaN          NaN            A
#
# [60 rows x 25 columns]

# %%
df2 = df2[df2['state'].isna()==False]#after checking the missing value,the nan in state is also nan in response

# %%
df2 = df2[df2['months_since_last_claim'].isna()==False]#after checking the missing value,the nan in months_since_last_claim is also nan in number_of_open_complaints

# %%
df2 = df2[df2['vehicle_class'].isna()==False] #after checking the missing value,the nan in vehicle_class is also nan in vehicle_size
#So we just drop one of them then we've droped for all
#Since it's not a big amount so we just drop it directly
#But the nan in vehicle type is a lot,se we need to deal with it.
#Since it's a catagorical value so I decide to use the most frequent value to replace nan

# %%
df2.shape
# Out:
# (9134, 25)

# %%
display(df2.isna().sum())
# Out:
# customer                            0
# state                               0
# customer_lifetime_value             0
# response                            0
# coverage                            0
# education                           0
# effective_to_date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim             0
# months_since_policy_inception       0
# number_of_open_complaints           0
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                       0
# vehicle_size                        0
# vehicle_type                     4591
# dtype: int64

# %%
df2['vehicle_type'].value_counts(dropna=False)
# Out:
# NaN    4591
# A      4543
# Name: vehicle_type, dtype: int64

# %%
df2['vehicle_type'] = df2['vehicle_type'].fillna('A')

# %%
df2['vehicle_type'].value_counts(dropna=False)
# Out:
# A    9134
# Name: vehicle_type, dtype: int64

# %% [markdown]
# # Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February.

# %%
df2['date'] = pd.to_datetime(df2['effective_to_date'])
df2.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 6  IW72280  California              5035.035257       No     Basic    Doctor
#
#   effective_to_date employmentstatus gender  income  ... number_of_policies  \
# 0           2/18/11         Employed      M   48029  ...                  9
# 1           1/18/11       Unemployed      F       0  ...                  1
# 2           2/10/11         Employed      M   22139  ...                  2
# 3           1/11/11         Employed      M   49078  ...                  2
# 6           2/14/11         Employed      F   37405  ...                  4
#
#       policy_type        policy  renew_offer_type  sales_channel  \
# 0  Corporate Auto  Corporate L3            Offer3          Agent
# 1   Personal Auto   Personal L3            Offer4    Call Center
# 2   Personal Auto   Personal L3            Offer3    Call Center
# 3  Corporate Auto  Corporate L3            Offer2         Branch
# 6  Corporate Auto  Corporate L2            Offer2         Branch
#
#    total_claim_amount  vehicle_class vehicle_size vehicle_type       date
# 0          292.800000  Four-Door Car      Medsize            A 2011-02-18
# 1          744.924331  Four-Door Car      Medsize            A 2011-01-18
# 2          480.000000            SUV      Medsize            A 2011-02-10
# 3          484.013411  Four-Door Car      Medsize            A 2011-01-11
# 6          287.556107  Four-Door Car      Medsize            A 2011-02-14
#
# [5 rows x 26 columns]

# %%
df2[df2['date']<'2011-04-01']
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   education effective_to_date employmentstatus gender  income  \
# 0                   College           2/18/11         Employed      M   48029
# 1                   College           1/18/11       Unemployed      F       0
# 2                  Bachelor           2/10/11         Employed      M   22139
# 3                   College           1/11/11         Employed      M   49078
# 6                    Doctor           2/14/11         Employed      F   37405
# ...                     ...               ...              ...    ...     ...
# 10903               College            1/7/11         Employed      M   59855
# 10904  High School or Below           2/24/11       Unemployed      M       0
# 10906               College            1/6/11         Employed      F   61146
# 10907              Bachelor            2/6/11         Employed      F   39837
# 10908               College           2/13/11         Employed      F   64195
#
#        ... number_of_policies     policy_type        policy  renew_offer_type  \
# 0      ...                  9  Corporate Auto  Corporate L3            Offer3
# 1      ...                  1   Personal Auto   Personal L3            Offer4
# 2      ...                  2   Personal Auto   Personal L3            Offer3
# 3      ...                  2  Corporate Auto  Corporate L3            Offer2
# 6      ...                  4  Corporate Auto  Corporate L2            Offer2
# ...    ...                ...             ...           ...               ...
# 10903  ...                  1   Personal Auto   Personal L2            Offer2
# 10904  ...                  2   Personal Auto   Personal L2            Offer1
# 10906  ...                  6   Personal Auto   Personal L3            Offer2
# 10907  ...                  2  Corporate Auto  Corporate L3            Offer1
# 10908  ...                  6   Personal Auto   Personal L1            Offer1
#
#        sales_channel  total_claim_amount  vehicle_class vehicle_size  \
# 0              Agent          292.800000  Four-Door Car      Medsize
# 1        Call Center          744.924331  Four-Door Car      Medsize
# 2        Call Center          480.000000            SUV      Medsize
# 3             Branch          484.013411  Four-Door Car      Medsize
# 6             Branch          287.556107  Four-Door Car      Medsize
# ...              ...                 ...            ...          ...
# 10903         Branch          355.200000   Two-Door Car      Medsize
# 10904         Branch          897.600000     Luxury SUV      Medsize
# 10906         Branch          273.018929  Four-Door Car      Medsize
# 10907            Web          381.306996     Luxury SUV      Medsize
# 10908         Branch          618.288849            SUV      Medsize
#
#       vehicle_type       date
# 0                A 2011-02-18
# 1                A 2011-01-18
# 2                A 2011-02-10
# 3                A 2011-01-11
# 6                A 2011-02-14
# ...            ...        ...
# 10903            A 2011-01-07
# 10904            A 2011-02-24
# 10906            A 2011-01-06
# 10907            A 2011-02-06
# 10908            A 2011-02-13
#
# [9134 rows x 26 columns]

# %% [markdown]
# # EDA (Exploratory Data Analysis) - Complete the following tasks to explore the data:

# %%
##Show DataFrame info.

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9134 entries, 0 to 10908
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       9134 non-null   object
#  1   state                          9134 non-null   object
#  2   customer_lifetime_value        9134 non-null   float64
#  3   response                       9134 non-null   object
#  4   coverage                       9134 non-null   object
#  5   education                      9134 non-null   object
#  6   effective_to_date              9134 non-null   object
#  7   employmentstatus               9134 non-null   object
#  8   gender                         9134 non-null   object
#  9   income                         9134 non-null   int64
#  10  location_code                  9134 non-null   object
#  11  marital_status                 9134 non-null   object
#  12  monthly_premium_auto           9134 non-null   int64
#  13  months_since_last_claim        9134 non-null   float64
#  14  months_since_policy_inception  9134 non-null   int64
#  15  number_of_open_complaints      9134 non-null   float64
#  16  number_of_policies             9134 non-null   int64
#  17  policy_type                    9134 non-null   object
#  18  policy                         9134 non-null   object
#  19  renew_offer_type               9134 non-null   object
#  20  sales_channel                  9134 non-null   object
#  21  total_claim_amount             9134 non-null   float64
#  22  vehicle_class                  9134 non-null   object
#  23  vehicle_size                   9134 non-null   object
#  24  vehicle_type                   9134 non-null   object
#  25  date                           9134 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(4), object(17)
# memory usage: 1.9+ MB

# %%
##Describe DataFrame.

# %%
df2.describe()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        months_since_last_claim  months_since_policy_inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# 25%                   6.000000                      24.000000
# 50%                  14.000000                      48.000000
# 75%                  23.000000                      71.000000
# max                  35.000000                      99.000000
#
#        number_of_open_complaints  number_of_policies  total_claim_amount
# count                9134.000000         9134.000000         9134.000000
# mean                    0.384388            2.966170          434.088794
# std                     0.910384            2.390182          290.500092
# min                     0.000000            1.000000            0.099007
# 25%                     0.000000            1.000000          272.258244
# 50%                     0.000000            2.000000          383.945434
# 75%                     0.000000            4.000000          547.514839
# max                     5.000000            9.000000         2893.239678

# %%
##Show a plot of the total number of responses.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.displot(df2['response'])

# %%
##Show a plot of the response rate by the sales channel.
#!pip install seanborn --upgrade
#import seaborn as sns

#sns.__version__

# %%
sns.histplot(x='sales_channel',hue='response',data=df2,stat='probability')
# Out:
# <AxesSubplot:xlabel='sales_channel', ylabel='Probability'>

# %%
##Show a plot of the response rate by the total claim amount.
sns.histplot(x='total_claim_amount',hue='response',data=df2,stat='probability')
# Out:
# <AxesSubplot:xlabel='total_claim_amount', ylabel='Probability'>

# %%
sns.histplot(x='income',hue='response',data=df2,stat='probability')
# Out:
# <AxesSubplot:xlabel='income', ylabel='Probability'>
